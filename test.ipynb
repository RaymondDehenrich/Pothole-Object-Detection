# %%
import torch
import torchvision
import torch.nn as nn
import albumentations as A
from albumentations.pytorch import ToTensorV2
from torchvision.models.detection import ssdlite320_mobilenet_v3_large
from torch.optim.lr_scheduler import MultiStepLR
from torchmetrics.detection.mean_ap import MeanAveragePrecision
from torchvision.datasets import CocoDetection
import torch.optim as optim
from torch.utils.data import DataLoader
import xml.etree.ElementTree as ET
import matplotlib.patches as patches
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def collate_fn(batch):
    """
    To handle the data loading as different images may have different number 
    of objects and to handle varying size tensors as well.
    """
    return tuple(zip(*batch))


def visualize_image_with_boxes(image, bounding_boxes):
    # Create a Matplotlib figure and axis
    fig, ax = plt.subplots(1)
    # Display the image
    image_data = np.transpose(image, (1, 2, 0))
    ax.imshow(image_data)  

    # Add bounding boxes to the image
    #print("in the visual:",bounding_boxes)
    #for box in bounding_boxes['boxes']:
    for box in bounding_boxes:
         #Note: box['boxes'][0] changed to box['boxes'][0][0] accounting for tensor in epoch loop, change if needed
        #print(box)
        xmin, ymin, xmax, ymax = box[0], box[1], box[2], box[3]
        #label = box['label']
        # Create a Rectangle patch
        rect = patches.Rectangle(
            (xmin, ymin), 
            xmax-xmin, 
            ymax-ymin, 
            linewidth=1, 
            edgecolor='r', 
            facecolor='none', 
            label=0
        )

        # Add the rectangle to the axis
        ax.add_patch(rect)

    # Show the image with bounding boxes
    plt.show()

# %%
def parse_annotation(annotation_folder):
    final_annotation =[]
    count=1
    for annotation_file in os.listdir(annotation_folder):
        tree = ET.parse(os.path.join(annotation_folder,annotation_file))
        root = tree.getroot()
        parse_annotate_file = []
        for obj in root.findall('object'):
            xmin = float(obj.find('bndbox/xmin').text)
            ymin = float(obj.find('bndbox/ymin').text)
            xmax = float(obj.find('bndbox/xmax').text)
            ymax = float(obj.find('bndbox/ymax').text)
            
            bounding_boxes=[
                xmin,
                ymin,
                xmax,
                ymax
            ]
            parse_annotate_file.append({'bbox':bounding_boxes,'category_id': 1})
        final_annotation.append({'image_id':count,'file_name':annotation_file.replace('.xml', '.png'),'annotations':parse_annotate_file})
        count+=1
    return final_annotation

# %%
def adjust_bounding_boxes(bounding_boxes, resize_scale_w, resize_scale_h):
    temp_box = []
    for box in bounding_boxes:
        xmin, ymin, xmax, ymax = box['bbox'][0], box['bbox'][1], box['bbox'][2], box['bbox'][3]
        xmin *= 1/resize_scale_w
        ymin *= 1/resize_scale_h
        xmax *= 1/resize_scale_w
        ymax *= 1/resize_scale_h
        adjusted_boxes=[
            xmin,
            ymin,
            xmax,
            ymax,
        ]
        temp_box.append({'bbox':adjusted_boxes,'category_id': 1})
    return temp_box

def resize_and_pad_image(image, target_size):
    # Calculate the aspect ratio
    aspect_ratio = image.shape[1] / image.shape[0]

    # Determine which dimension (width or height) to fix and resize
    if aspect_ratio > 1:  # Image is wider
        new_width = target_size
        new_height = int(target_size / aspect_ratio)
    else:  # Image is taller or square
        new_height = target_size
        new_width = int(target_size * aspect_ratio)

    # Resize the image while preserving aspect ratio
    resized_image = cv2.resize(image, (new_width, new_height))

    # Pad the image to the desired dimensions
    pad_x = max(0, target_size - new_width)
    pad_y = max(0, target_size - new_height)
    padded_image = cv2.copyMakeBorder(resized_image, 0, pad_y, 0, pad_x, cv2.BORDER_CONSTANT, value=0)

    return padded_image

# %%
class CustomCocoDetection(CocoDetection):
    def __init__(self, root,custom_annotations,transforms=None):
        self.transforms = transforms
        self.root = root
        self.custom_annotations = parse_annotation(custom_annotations)
        self.transforms = transforms
        self.adjusted = 0
    
    def __len__(self):
        return len(self.custom_annotations)
    
    def __getitem__(self, index):
        img = cv2.imread(os.path.join(self.root, self.custom_annotations[index]['file_name']))
        #img = Image.open(os.path.join(self.root, self.custom_annotations[index]['file_name']))
        #plt.imshow(img)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
        #img = np.array(img)
        custom_annotations = self.custom_annotations[index].copy()
        target_size = 300  # Desired input size (e.g., 400x400)
        #1 = width, 0 = height
        aspect_ratio = img.shape[1] / img.shape[0]
        # Calculate aspect ratio of the original image
        resize_scale_w=1
        resize_scale_h=1
        # Determine which dimension to fix (width or height)
        if aspect_ratio >= 1:  # Image is wider
            resize_scale_w = img.shape[1]/target_size
            resize_scale_h = img.shape[1]/target_size # Scale height by the same factor
        elif aspect_ratio < 1:  # Image is taller or square
            resize_scale_h = img.shape[0]/target_size
            resize_scale_w = img.shape[0]/target_size
        img = resize_and_pad_image(img,target_size=target_size)
        if(self.adjusted==0):
            custom_annotations['annotations'] = adjust_bounding_boxes(custom_annotations['annotations'],resize_scale_w,resize_scale_h)
            self.adjusted=1
        elif(self.adjusted==1):
            custom_annotations = self.custom_annotations[index].copy()
            custom_annotations['annotations'] = adjust_bounding_boxes(custom_annotations['annotations'],resize_scale_w,resize_scale_h)
        #TODO: rescale and pad needed
        # Convert (x1, y1, x2, y2) format to (x, y, width, height) format
        coco_annotations = []
        labels =[]
        boxes=[]
        for bbox in custom_annotations['annotations']:
            x1, y1, x2, y2 = bbox['bbox']
            x_2 = float(x2)
            y_2 = float(y2)
            x = float(x1)
            y = float(y1)
            #print(x,y,x_2,y_2)
            if x_2 >= target_size:
                x_2 = target_size-1
            if y_2 >= target_size:
                y_2 = target_size-1
            #print("========")
            #print(x, y, x_2, y_2)
            if x_2 <= x or y_2 <= y:
                # Handle the invalid bounding box, e.g., by skipping or correcting it.
                continue
            else:
                boxes.append([x, y, x_2, y_2])
                labels.append(1)
        #TODO: AREA,
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0]) if len(boxes) > 0 \
            else torch.as_tensor(boxes, dtype=torch.float32)
        iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)
        labels = torch.as_tensor(labels, dtype=torch.int64)
        # Convert custom annotations to COCO format
        #print("in loader:",boxes)
        coco_target = {
            "boxes": boxes,
            'labels':labels,
            'area':area,
            'iscrowd':iscrowd,
            "image_id": torch.as_tensor(index,dtype=torch.int64),
            #"file_name": self.custom_annotations[index]['file_name'],
        }
        img /=255.0
        if self.transforms:
            sample = self.transforms(image = img,
                                     bboxes = coco_target['boxes'],
                                     labels = labels)
            image_resized = sample['image']
            coco_target['boxes'] = torch.Tensor(sample['bboxes'])
        if np.isnan((coco_target['boxes']).numpy()).any() or coco_target['boxes'].shape == torch.Size([0]):
            coco_target['boxes'] = torch.zeros((0, 4), dtype=torch.int64)
        if index ==1:
            print(self.custom_annotations[index])
        return image_resized, coco_target

# %%
def get_train_transform():
    return A.Compose([
        ToTensorV2(p=1.0),
    ], bbox_params={
        'format': 'pascal_voc',
        'label_fields': ['labels']
    })

# %%
dataset = CustomCocoDetection('./Dataset/images','./Dataset/annotations/',transforms=get_train_transform())
val_set = CustomCocoDetection('./Validate/images','./Validate/annotations/',transforms=get_train_transform())

# %%
#print(dataset.test(0)[0])
#temp,temp1 =val_set.__getitem__(1) 
#TODO: Error karena variable copy nge edit variable original, need rework and refactoring.
#print(temp1['file_name'])
#print(temp.shape)
#visualize_image_with_boxes(temp,temp1)
#visualize_image_with_boxes(dataset.__getitem__(1)[0],dataset.__getitem__(1)[1]['annotations'])

# %%
class PotholeDetector(nn.Module):
    def __init__(self):
        super(PotholeDetector, self).__init__()
        self.base_model = ssdlite320_mobilenet_v3_large(num_classes=2,pretrained=False)


    def forward(self, image,target):
        #print(image.shape)
        return self.base_model(image,target)

# %%
trainloader = DataLoader(dataset,batch_size=10,shuffle=True,collate_fn=collate_fn)
val_loader = DataLoader(val_set,batch_size=10,shuffle=True,collate_fn=collate_fn)

# %%
model = PotholeDetector()
model.train()
model = model.to(device)
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(
        params, lr=0.001, momentum=0.9, nesterov=True
    )
scheduler = MultiStepLR(
        optimizer=optimizer, milestones=[45], gamma=0.1, verbose=True
    )
# Out:
# c:\Users\CrispySalt\.conda\envs\person_test\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\CrispySalt\.conda\envs\person_test\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Adjusting learning rate of group 0 to 1.0000e-03.

# %%
for epoch in range(0,200):  # loop over the dataset multiple times
    print(f"Epoch [{epoch}]")
    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        optimizer.zero_grad()
        images, labels = data
        images = list(image.to(device) for image in images)

        targets = [{k: v.to(device) for k, v in t.items()} for t in labels]

        outputs= model(images,targets)
        #print('pass')
        losses = sum(loss for loss in outputs.values())

        losses.backward()
        optimizer.step()

        # print statistics
        running_loss += losses.item()
        #print(f"Iteration [{i}]: Loss = {running_loss}\n")
        if (i % 50 == 0 and i!=0):    # print every 2000 mini-batches
            print(f'iter [{i}]| loss: {running_loss / 50:.20f} ')
            running_loss = 0.0
    scheduler.step()
    print()
# Out:
# Epoch [0]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 7.50062845230102581695
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [1]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 6.14656947135925335601
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [2]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 5.63475920677185015961
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [3]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 5.17124494552612290477
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [4]
# iter [50]| loss: 4.86846829414367654465
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [5]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 4.54423783779144319084
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [6]
# iter [50]| loss: 4.36580803394317662480
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [7]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 4.12546203136444056270
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [8]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 4.00255280494689902326
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [9]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 3.80643175601959216081
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [10]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 3.61159672260284425604
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [11]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 3.47367862701416019178
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [12]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 3.32953455924987773429
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [13]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 3.21285546779632547043
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [14]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 3.08694518566131570481
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [15]
# iter [50]| loss: 2.97116272449493390440
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [16]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 2.87678111076354969811
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [17]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 2.79579445600509624015
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [18]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 2.63990617752075173996
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [19]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 2.59634934902191183426
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [20]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 2.53535169124603276813
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [21]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 2.38854551553726190960
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [22]
# iter [50]| loss: 2.34126816511154167699
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [23]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 2.23928716182708731353
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [24]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 2.19400974512100210845
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [25]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 2.14211029052734369671
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [26]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 2.05103437185287473810
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [27]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.99769767284393306994
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [28]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.93315122604370115411
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [29]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.87844300031661992634
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [30]
# iter [50]| loss: 1.80333802461624137514
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [31]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.79018239021301273084
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [32]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.73275581598281869233
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [33]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.66191268920898438388
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [34]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.65000691890716555399
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [35]
# iter [50]| loss: 1.58036300182342537290
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [36]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.53221778392791740941
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [37]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.51304229736328132994
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [38]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.44271964192390433901
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [39]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.45030527353286742276
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [40]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.41827351808547974521
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [41]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.37079335570335381078
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [42]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.35805665850639334380
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [43]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.30010868430137627172
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Epoch [44]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.26682204604148873628
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [45]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.21157207012176515448
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [46]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.22472607374191277962
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [47]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.21511877417564395643
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [48]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.19413992881774899679
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [49]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.19450524926185597252
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [50]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.20629079818725593043
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [51]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.16494295597076424897
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [52]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.18962683081626896531
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [53]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.18951077461242671340
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [54]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.17319979071617130906
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [55]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.17398507475852964532
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [56]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.13934624910354620475
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [57]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.16915636420249935412
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [58]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.17285647630691536314
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [59]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.16197189688682556152
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [60]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.16168689608573916239
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [61]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.17619828939437875981
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [62]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.16327473282814031208
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [63]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.16920405745506283957
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [64]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.14378683328628549809
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [65]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.13355927228927622075
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [66]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.13295433044433591085
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [67]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.14293287634849538570
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [68]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.13140990138053898484
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [69]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.14304240226745612574
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [70]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.13868387103080759282
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [71]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.12102293014526366299
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [72]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.09959074497222908384
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [73]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.10644537329673764425
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [74]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.15238823294639591843
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [75]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.11477926492691037375
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [76]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.09853399515151983756
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [77]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.10784801602363591755
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [78]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.10743551969528208900
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [79]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.12342300772666936481
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [80]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.06773222923278798824
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [81]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.08069434642791750711
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [82]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.10552971005439748531
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [83]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.11297896504402160645
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [84]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.09561446428298947531
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [85]
# iter [50]| loss: 1.06568205356597900391
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [86]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.05117696881294242495
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [87]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.05453048825263984156
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [88]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.10530293464660633873
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [89]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.10242271542549130636
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [90]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.08326112389564510607
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [91]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.06181359171867373270
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [92]
# iter [50]| loss: 1.08095816016197199261
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [93]
# iter [50]| loss: 1.05821660041809084696
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [94]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.04638103723525999200
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [95]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.06885655283927927250
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [96]
# iter [50]| loss: 1.05133410573005670052
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [97]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.04366999268531790435
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [98]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.01275714755058299232
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [99]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.06017044663429249596
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [100]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.05205155611038203567
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [101]
# iter [50]| loss: 1.04586439132690434128
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [102]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.03905426144599921656
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [103]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.03971725940704340374
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [104]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.03894139170646671033
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [105]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.04362118124961855692
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [106]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.00694069981575018424
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [107]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.02854946136474612040
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [108]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.03803456425666817964
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [109]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.04127358675003045541
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [110]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.05085690855979918545
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [111]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.01607318401336677027
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [112]
# iter [50]| loss: 1.02285354256629945624
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [113]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.03746991872787486244
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [114]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.01231864333152765667
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [115]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.00996532678604133970
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [116]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.99723104953765873137
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [117]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.01642676353454586291
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [118]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.00147620439529427827
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [119]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.00161664366722114039
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [120]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.99143832802772524637
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [121]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.99553533196449284226
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [122]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.01357386350631717420
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [123]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 1.02807280182838445270
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [124]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.95457457423210145819
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [125]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.99353184103965763718
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [126]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.99285977840423589313
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [127]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.99832982301712036577
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [128]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.98737913727760318050
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [129]
# iter [50]| loss: 0.99550359606742855334
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [130]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.94507008314132689986
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [131]
# iter [50]| loss: 0.98556848049163814363
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [132]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.96181279540061948019
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [133]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.98903598427772521084
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [134]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.96406372785568239525
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [135]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.95552268505096438211
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [136]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.94375339746475217506
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [137]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.99105689764022830701
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [138]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.97430889487266536531
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [139]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.95782539010047917927
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [140]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.94515374898910520240
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [141]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.96691433548927308017
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [142]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.94180637717247006613
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [143]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.92904165029525753727
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [144]
# iter [50]| loss: 0.94306724786758422407
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [145]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.93607372164726254660
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [146]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.93009618759155276990
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [147]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.93320565342903138983
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [148]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.95067623853683469459
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [149]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.93843316197395321154
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [150]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.92731055140495299849
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [151]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.93728969216346735838
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [152]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.94967446565628055311
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [153]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.94592634797096253330
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [154]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.93169702172279356134
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [155]
# iter [50]| loss: 0.90380957365036007634
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [156]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.90902717947959899014
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [157]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.92427757024765011540
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [158]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.92997671723365782359
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [159]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.90136825323104863283
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [160]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.92193806052207949442
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [161]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.91121491789817810059
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [162]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.89233964562416079325
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [163]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.91053872704505922631
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [164]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.88991940736770624998
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [165]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.90636995673179621136
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [166]
# iter [50]| loss: 0.89779439687728879171
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [167]
# iter [50]| loss: 0.87993020057678217327
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [168]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.91747269988059998447
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [169]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.91462076783180235040
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [170]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.89847576737403866964
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [171]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.88981213808059689274
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [172]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.88205809473991392267
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [173]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.88097817182540893999
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [174]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.88411129832267765227
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [175]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.86818077564239504174
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [176]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.87752905488014221191
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [177]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.88570286273956300160
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [178]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.88094562530517572796
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [179]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.86045742034912109375
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [180]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.87884589672088619938
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [181]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.88352158904075617230
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [182]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.87050122320652012498
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [183]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.85398543477058408424
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [184]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.89416784882545474744
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [185]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.85282184243202208140
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [186]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.84619591474533084607
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [187]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.85497353076934812233
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [188]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.84977370500564575195
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [189]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.85504696130752566585
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [190]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.86737914919853209561
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [191]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.83585509181022643599
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [192]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.83441750407218928665
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [193]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.83731765866279606048
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [194]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.86509810328483582875
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [195]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.84343277931213378462
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [196]
# iter [50]| loss: 0.82805567383766176537
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [197]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.83468490123748784182
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [198]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.82946633636951450086
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Epoch [199]
# {'image_id': 2, 'file_name': 'potholes101.png', 'annotations': [{'bbox': [158.0, 164.0, 235.0, 185.0], 'category_id': 1}, {'bbox': [319.0, 186.0, 386.0, 211.0], 'category_id': 1}]}
# iter [50]| loss: 0.83617220640182499114
# Adjusting learning rate of group 0 to 1.0000e-04.

# %%
model.eval()
target = []
preds = []
#args = vars(parser.parse_args())
for i, data in enumerate(val_loader, 0):
    images,targets = data
    images = list(image.to(device) for image in images)
    targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
    with torch.no_grad():
            outputs = model(images, targets)
    
    images = list(image.to('cpu') for image in images)
    outputs = [{k: v.to('cpu') for k, v in t.items()} for t in outputs]
    #iou_threshold = 0.5
    #print(outputs)
    #print("test")
    if len(outputs[0]['boxes']) != 0:
        for i,output in enumerate(outputs,0):
                #print(output)
                boxes = output['boxes'].data.numpy()
                scores = output['scores'].data.numpy()
                # Filter out boxes according to `detection_threshold`.
                boxes = boxes[scores >= 0.25].astype(np.int32)
                draw_boxes = boxes.copy()
                #print(draw_boxes)
                #print(output)
                #print("===")
                #keep_indices = torchvision.ops.nms(output['boxes'], output['scores'], iou_threshold)
                #selected_boxes = output
                #print(len(selected_boxes['boxes']))
                #print("===========================")
                #selected_boxes['boxes']=selected_boxes['boxes'][keep_indices]
                #print(len(selected_boxes['boxes']))
                #visualize_image_with_boxes(images[i],draw_boxes)
                #temp = input("hello")

# Perform NMS
    #keep_indices = torchvision.ops.nms(boxes, scores, iou_threshold)
    for i in range(len(images)):
            true_dict = dict()
            preds_dict = dict()
            true_dict['boxes'] = targets[i]['boxes'].detach().cpu()
            true_dict['labels'] = targets[i]['labels'].detach().cpu()
            preds_dict['boxes'] = outputs[i]['boxes'].detach().cpu()
            preds_dict['scores'] = outputs[i]['scores'].detach().cpu()
            preds_dict['labels'] = outputs[i]['labels'].detach().cpu()
            preds.append(preds_dict)
            target.append(true_dict)
metric = MeanAveragePrecision()
metric.update(preds, target)
metric_summary = metric.compute()
print(f"mAP_50: {metric_summary['map_50']*100:.3f}")
print(f"mAP_50_95: {metric_summary['map']*100:.3f}")
# Out:
# test
# test
# test
# {'image_id': 2, 'file_name': 'potholes11.png', 'annotations': [{'bbox': [139.0, 153.0, 260.0, 237.0], 'category_id': 1}, {'bbox': [36.0, 170.0, 67.0, 199.0], 'category_id': 1}]}
# test
# test
# test
# test
# test
# test
# test
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\AI\pothole_v3\test.ipynb Cell 13 line 4
#      <a href='vscode-notebook-cell:/d%3A/AI/pothole_v3/test.ipynb#X15sZmlsZQ%3D%3D?line=46'>47</a>             preds.append(preds_dict)
#      <a href='vscode-notebook-cell:/d%3A/AI/pothole_v3/test.ipynb#X15sZmlsZQ%3D%3D?line=47'>48</a>             target.append(true_dict)
# ---> <a href='vscode-notebook-cell:/d%3A/AI/pothole_v3/test.ipynb#X15sZmlsZQ%3D%3D?line=48'>49</a> metric = MeanAveragePrecision()
#      <a href='vscode-notebook-cell:/d%3A/AI/pothole_v3/test.ipynb#X15sZmlsZQ%3D%3D?line=49'>50</a> metric.update(preds, target)
#      <a href='vscode-notebook-cell:/d%3A/AI/pothole_v3/test.ipynb#X15sZmlsZQ%3D%3D?line=50'>51</a> metric_summary = metric.compute()
#
# File c:\Users\CrispySalt\.conda\envs\person_test\Lib\site-packages\torchmetrics\detection\mean_ap.py:385, in MeanAveragePrecision.__init__(self, box_format, iou_type, iou_thresholds, rec_thresholds, max_detection_thresholds, class_metrics, extended_summary, average, backend, **kwargs)
#     382 super().__init__(**kwargs)
#     384 if not _PYCOCOTOOLS_AVAILABLE:
# --> 385     raise ModuleNotFoundError(
#     386         "`MAP` metric requires that `pycocotools` installed."
#     387         " Please install with `pip install pycocotools` or `pip install torchmetrics[detection]`"
#     388     )
#     389 if not _TORCHVISION_GREATER_EQUAL_0_8:
#     390     raise ModuleNotFoundError(
#     391         "`MeanAveragePrecision` metric requires that `torchvision` version 0.8.0 or newer is installed."
#     392         " Please install with `pip install torchvision>=0.8` or `pip install torchmetrics[detection]`."
#     393     )
#
# ModuleNotFoundError: `MAP` metric requires that `pycocotools` installed. Please install with `pip install pycocotools` or `pip install torchmetrics[detection]`

# %%
#TODO: Cleanup code, new optimizer, losses, etc. create evaluator
